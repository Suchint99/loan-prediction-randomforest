# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df.head()
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       500.000000         500.000000  482.000000        486.000000
# mean       5493.644000        1506.307840  144.020747        342.543210
# std        6515.668972        2134.432188   82.344919         63.834977
# min         150.000000           0.000000   17.000000         12.000000
# 25%        2874.500000           0.000000  100.000000        360.000000
# 50%        3854.000000        1125.500000  126.500000        360.000000
# 75%        5764.000000        2253.250000  161.500000        360.000000
# max       81000.000000       20000.000000  700.000000        480.000000
#
#        Credit_History
# count      459.000000
# mean         0.843137
# std          0.364068
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
X=df.drop(['Loan_Status','Loan_ID'], axis=1)
y=df['Loan_Status']

# %%
X
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 495  Female     Yes          1      Graduate            No             3326
# 496    Male     Yes          0  Not Graduate            No             2600
# 497    Male     Yes          0      Graduate            No             4625
# 498    Male     Yes          1      Graduate           Yes             2895
# 499    Male      No          0      Graduate            No             6283
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 495              913.0       105.0              84.0             1.0
# 496             1700.0       107.0             360.0             1.0
# 497             2857.0       111.0              12.0             NaN
# 498                0.0        95.0             360.0             1.0
# 499             4416.0       209.0             360.0             0.0
#
#     Property_Area
# 0           Urban
# 1           Rural
# 2           Urban
# 3           Urban
# 4           Urban
# ..            ...
# 495     Semiurban
# 496         Rural
# 497         Urban
# 498     Semiurban
# 499         Rural
#
# [500 rows x 11 columns]

# %%
X.isnull().sum()
# Out:
# Gender                9
# Married               3
# Dependents           12
# Education             0
# Self_Employed        27
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     14
# Credit_History       41
# Property_Area         0
# dtype: int64

# %%
X['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    387
# 0.0     72
# Name: count, dtype: int64

# %%
X['Gender'].value_counts()
# Out:
# Gender
# Male      400
# Female     91
# Name: count, dtype: int64

# %%
X['Gender'].fillna("Male", inplace=True)
X.isnull().sum()
# Out:
# C:\Users\astha\AppData\Local\Temp\ipykernel_6572\3052673247.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Gender'].fillna("Male", inplace=True)
# Gender                0
# Married               3
# Dependents           12
# Education             0
# Self_Employed        27
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     14
# Credit_History       41
# Property_Area         0
# dtype: int64

# %%
X['Married'].value_counts()
# Out:
# Married
# Yes    322
# No     175
# Name: count, dtype: int64

# %%
X['Married'].fillna("Yes", inplace=True)
X.isnull().sum()
# Out:
# C:\Users\astha\AppData\Local\Temp\ipykernel_6572\2019185119.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Married'].fillna("Yes", inplace=True)
# Gender                0
# Married               0
# Dependents           12
# Education             0
# Self_Employed        27
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     14
# Credit_History       41
# Property_Area         0
# dtype: int64

# %%
X['Dependents'].value_counts()
# Out:
# Dependents
# 0     288
# 1      81
# 2      79
# 3+     40
# Name: count, dtype: int64

# %%
X['Dependents'].fillna(0,inplace=True)
# Out:
# C:\Users\astha\AppData\Local\Temp\ipykernel_6572\714843871.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Dependents'].fillna(0,inplace=True)

# %%
X['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     407
# Yes     66
# Name: count, dtype: int64

# %%
X['Self_Employed'].fillna('No',inplace=True)
# Out:
# C:\Users\astha\AppData\Local\Temp\ipykernel_6572\4131977900.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Self_Employed'].fillna('No',inplace=True)

# %%
mean_loan=X['LoanAmount'].mean()
X['LoanAmount'].fillna(mean_loan,inplace=True)
# Out:
# C:\Users\astha\AppData\Local\Temp\ipykernel_6572\1190317798.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['LoanAmount'].fillna(mean_loan,inplace=True)

# %%
X.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       41
# Property_Area         0
# dtype: int64

# %%
X['Loan_Amount_Term'].fillna(X['Loan_Amount_Term'].mean(),inplace=True)

X['Credit_History'].fillna(X['Credit_History'].mean(),inplace=True)

X.isnull().sum()
# Out:
# C:\Users\astha\AppData\Local\Temp\ipykernel_6572\1170272870.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Loan_Amount_Term'].fillna(X['Loan_Amount_Term'].mean(),inplace=True)
# C:\Users\astha\AppData\Local\Temp\ipykernel_6572\1170272870.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Credit_History'].fillna(X['Credit_History'].mean(),inplace=True)
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
X
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 495  Female     Yes          1      Graduate            No             3326
# 496    Male     Yes          0  Not Graduate            No             2600
# 497    Male     Yes          0      Graduate            No             4625
# 498    Male     Yes          1      Graduate           Yes             2895
# 499    Male      No          0      Graduate            No             6283
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  144.020747             360.0        1.000000
# 1               1508.0  128.000000             360.0        1.000000
# 2                  0.0   66.000000             360.0        1.000000
# 3               2358.0  120.000000             360.0        1.000000
# 4                  0.0  141.000000             360.0        1.000000
# ..                 ...         ...               ...             ...
# 495              913.0  105.000000              84.0        1.000000
# 496             1700.0  107.000000             360.0        1.000000
# 497             2857.0  111.000000              12.0        0.843137
# 498                0.0   95.000000             360.0        1.000000
# 499             4416.0  209.000000             360.0        0.000000
#
#     Property_Area
# 0           Urban
# 1           Rural
# 2           Urban
# 3           Urban
# 4           Urban
# ..            ...
# 495     Semiurban
# 496         Rural
# 497         Urban
# 498     Semiurban
# 499         Rural
#
# [500 rows x 11 columns]

# %%
X=pd.get_dummies(X)

# %%
X
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  144.020747             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# ..               ...                ...         ...               ...
# 495             3326              913.0  105.000000              84.0
# 496             2600             1700.0  107.000000             360.0
# 497             4625             2857.0  111.000000              12.0
# 498             2895                0.0   95.000000             360.0
# 499             6283             4416.0  209.000000             360.0
#
#      Credit_History  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 0          1.000000          False         True        True        False
# 1          1.000000          False         True       False         True
# 2          1.000000          False         True       False         True
# 3          1.000000          False         True       False         True
# 4          1.000000          False         True        True        False
# ..              ...            ...          ...         ...          ...
# 495        1.000000           True        False       False         True
# 496        1.000000          False         True       False         True
# 497        0.843137          False         True       False         True
# 498        1.000000          False         True       False         True
# 499        0.000000          False         True        True        False
#
#      Dependents_0  ...  Dependents_1  Dependents_2  Dependents_3+  \
# 0           False  ...         False         False          False
# 1           False  ...          True         False          False
# 2           False  ...         False         False          False
# 3           False  ...         False         False          False
# 4           False  ...         False         False          False
# ..            ...  ...           ...           ...            ...
# 495         False  ...          True         False          False
# 496         False  ...         False         False          False
# 497         False  ...         False         False          False
# 498         False  ...          True         False          False
# 499         False  ...         False         False          False
#
#      Education_Graduate  Education_Not Graduate  Self_Employed_No  \
# 0                  True                   False              True
# 1                  True                   False              True
# 2                  True                   False             False
# 3                 False                    True              True
# 4                  True                   False              True
# ..                  ...                     ...               ...
# 495                True                   False              True
# 496               False                    True              True
# 497                True                   False              True
# 498                True                   False             False
# 499                True                   False              True
#
#      Self_Employed_Yes  Property_Area_Rural  Property_Area_Semiurban  \
# 0                False                False                    False
# 1                False                 True                    False
# 2                 True                False                    False
# 3                False                False                    False
# 4                False                False                    False
# ..                 ...                  ...                      ...
# 495              False                False                     True
# 496              False                 True                    False
# 497              False                False                    False
# 498               True                False                     True
# 499              False                 True                    False
#
#      Property_Area_Urban
# 0                   True
# 1                  False
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 495                False
# 496                False
# 497                 True
# 498                False
# 499                False
#
# [500 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.30)
X_train.shape
X_test.shape
y_test.shape
# Out:
# (150,)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X,y)
model.score(X,y)
# Out:
# C:\Users\astha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.808

# %%
print(model.score(X_test, y_test))
# Out:
# 0.78

# %%
gender=input("What is your gender:")
married=input("Married:")
dependents=int(input("dependents value:"))
Education=input("enter your education")
SelfEmployed=input("Self Employed:")
Applicantincome=int(input("enter applicant income"))
coapplicantincome=int(input("enter co applicant income:"))
loanamount=int(input("enter loan amount:"))
loanamountterm=int(input("enter loan amount term:"))
credithistory=int(input("enter credit history:"))
propertyarea=input("enter property area:")

# %%
data = [[gender,married,dependents,Education,SelfEmployed,Applicantincome,coapplicantincome,loanamount,loanamountterm,credithistory,propertyarea]]

# %%
print(data)
# Out:
# [['Male', 'Yes', 1, 'Graduate', 'No', 3000, 0, 200, 12, 0, 'Urban']]

# %%
newdf = pd.DataFrame(data, columns = ['Gender','Married','Dependents','Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area'])
newdf
# Out:
#   Gender Married  Dependents Education Self_Employed  ApplicantIncome  \
# 0   Male     Yes           1  Graduate            No             3000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0         200                12               0
#
#   Property_Area
# 0         Urban

# %%
newdf = pd.get_dummies(newdf)

# %%
newdf
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0           1             3000                  0         200
#
#    Loan_Amount_Term  Credit_History  Gender_Male  Married_Yes  \
# 0                12               0         True         True
#
#    Education_Graduate  Self_Employed_No  Property_Area_Urban
# 0                True              True                 True

# %%
missing_cols = set( X_train.columns ) - set( newdf.columns )

# %%
missing_cols
# Out:
# {'Dependents_0',
#  'Dependents_1',
#  'Dependents_2',
#  'Dependents_3+',
#  'Education_Not Graduate',
#  'Gender_Female',
#  'Married_No',
#  'Property_Area_Rural',
#  'Property_Area_Semiurban',
#  'Self_Employed_Yes'}

# %%
for c in missing_cols:
    newdf[c] = 0

# %%
newdf
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0           1             3000                  0         200
#
#    Loan_Amount_Term  Credit_History  Gender_Male  Married_Yes  \
# 0                12               0         True         True
#
#    Education_Graduate  Self_Employed_No  ...  Self_Employed_Yes  \
# 0                True              True  ...                  0
#
#    Property_Area_Semiurban  Married_No  Education_Not Graduate  Dependents_1  \
# 0                        0           0                       0             0
#
#    Dependents_2  Dependents_0  Gender_Female  Property_Area_Rural  \
# 0             0             0              0                    0
#
#    Dependents_3+
# 0              0
#
# [1 rows x 21 columns]

# %%
newdf = newdf[X_train.columns]
newdf
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             3000                  0         200                12
#
#    Credit_History  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 0               0              0         True           0         True
#
#    Dependents_0  ...  Dependents_1  Dependents_2  Dependents_3+  \
# 0             0  ...             0             0              0
#
#    Education_Graduate  Education_Not Graduate  Self_Employed_No  \
# 0                True                       0              True
#
#    Self_Employed_Yes  Property_Area_Rural  Property_Area_Semiurban  \
# 0                  0                    0                        0
#
#    Property_Area_Urban
# 0                 True
#
# [1 rows x 21 columns]

# %%
yp=model.predict(newdf)
print(yp)
if (yp[0]=='Y'):
    print("Your Loan is approved, Please contact at HDFC Bank Any Branch for further processing")
else:
    print("Sorry ! Your Loan is not approved")
# Out:
# ['Y']
# Your Loan is approved, Please contact at HDFC Bank Any Branch for further processing
